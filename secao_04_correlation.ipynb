# %%
import numpy as np
import seaborn as sns

# %%
xx = np.array([-0.51,51.2])
yy = np.array([0.33,51.6])
means = [xx.mean(),yy.mean()]
stds = [xx.std()/3,yy.std()/3]
corr = .3 # correlação entre os pontos - 0 aleatório - -1/+1 mais relação
covs = [
    [stds[0]**2,stds[0]*stds[1]*corr],
    [stds[0]*stds[1]*corr, stds[1]**2]
]

m = np.random.multivariate_normal(means, covs, 1000).T

# %%
import pandas as pd

# %%
df = pd.DataFrame(m).T
df.columns = ['X', 'Y']
df.head()
# Out:
#            X          Y
# 0  21.573706  34.683852
# 1  33.411293  41.464464
# 2  38.994916  26.013934
# 3  26.790196  18.587207
# 4  33.776121  33.997790

# %%
sns.scatterplot(df, x='X', y='Y')
sns.despine()
